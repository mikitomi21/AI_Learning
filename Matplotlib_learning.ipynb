# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(0,6.4,0.1)
y = np.sin(x)
plt.plot(x,y)

# %%
x = [0, 5, 5, 0]
y = [0, 0, 5, 5]
plt.plot(x,y, 'bo')

# %%
x = [0, 5, 5, 0, 0]
y = [0, 0, 5, 5, 0]
plt.plot(x,y)
