# %%
import pandas as pd

df = pd.read_csv("pokemon_data.csv")

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1']]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.iloc[:5]
# df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.iloc[3][1]
# Out:
# 'VenusaurMega Venusaur'

# %%
for index, row in df.iterrows():
    print(index, row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
query = df.loc[df["Type 1"]=="Ice"]
query.iloc[:5]
# Out:
#        #       Name Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 133  124       Jynx    Ice  Psychic    455   65      50       35      115
# 156  144   Articuno    Ice   Flying    580   90      85      100       95
# 238  220     Swinub    Ice   Ground    250   50      50       40       30
# 239  221  Piloswine    Ice   Ground    450  100     100       80       60
# 243  225   Delibird    Ice   Flying    330   45      55       45       65
#
#      Sp. Def  Speed  Generation  Legendary
# 133       95     95           1      False
# 156      125     85           1       True
# 238       30     50           2      False
# 239       60     50           2      False
# 243       45     75           2      False

# %%
query = df.sort_values(["Type 1","HP"], ascending=[1,0])
query.iloc[10:20]
# Out:
#        #               Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 54    49           Venomoth    Bug  Poison    450  70      65       60
# 132  123            Scyther    Bug  Flying    500  70     110       80
# 182  168            Ariados    Bug  Poison    390  70      90       70
# 228  212             Scizor    Bug   Steel    500  70     130      100
# 229  212  ScizorMega Scizor    Bug   Steel    600  70     150      140
# 308  284         Masquerain    Bug  Flying    414  70      60       62
# 461  414             Mothim    Bug  Flying    424  70      94       50
# 463  416          Vespiquen    Bug  Flying    474  70      80      102
# 619  558            Crustle    Bug    Rock    475  70      95      125
# 650  589         Escavalier    Bug   Steel    495  70     135      105
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 54        90       75     90           1      False
# 132       55       80    105           1      False
# ...

# %%
# df['Total'] = df['HP'] + df['Attack'] + df['Defense']
# df = df.drop(columns=['Total'])
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df.head(10)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]


df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Generation  Legendary   Total  \
# 0  1                  Bulbasaur  Grass  Poison           1      False   208.0
# 1  2                    Ivysaur  Grass  Poison           1      False   265.0
# 2  3                   Venusaur  Grass  Poison           1      False   345.0
# 3  3      VenusaurMega Venusaur  Grass  Poison           1      False   425.0
# 4  4                 Charmander   Fire     NaN           1      False   817.0
# 5  5                 Charmeleon   Fire     NaN           1      False  1076.0
# 6  6                  Charizard   Fire  Flying           1      False  1424.0
# 7  6  CharizardMega Charizard X   Fire  Dragon           1      False  1724.0
# 8  6  CharizardMega Charizard Y   Fire  Flying           1      False  1694.0
# 9  7                   Squirtle  Water     NaN           1      False   843.0
#
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  45      49       49       65       65     45
# ...

# %%
# df.to_csv('modified.csv', index=False)
# df.to_excel('modified.xlsx', index=False)
# df.to_csv('modified.txt', index=False, sep='\t')

# %%
test = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
test.reset_index(drop=True, inplace=True)
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
import re

# df.loc[~df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# ~ meant 'not'
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# ^ it start with
# [a-z]* some letters from zero to ...
# re.I ignore size of letters
# Out:
#        #                 Name    Type 1    Type 2  Generation  Legendary  \
# 20    16               Pidgey    Normal    Flying           1      False
# 21    17            Pidgeotto    Normal    Flying           1      False
# 22    18              Pidgeot    Normal    Flying           1      False
# 23    18  PidgeotMega Pidgeot    Normal    Flying           1      False
# 30    25              Pikachu  Electric       NaN           1      False
# 136  127               Pinsir       Bug       NaN           1      False
# 137  127    PinsirMega Pinsir       Bug    Flying           1      False
# 186  172                Pichu  Electric       NaN           2      False
# 219  204               Pineco       Bug       NaN           2      False
# 239  221            Piloswine       Ice    Ground           2      False
# 438  393               Piplup     Water       NaN           4      False
# 558  499              Pignite      Fire  Fighting           5      False
# ...

# %%
# df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
# df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

# df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True

df = pd.read_csv('modified.csv')

# %%
df.groupby(['Type 1']).mean().sort_values('Total', ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %%
df.groupby(['Type 1']).count()['#'].sort_values(ascending=False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: #, dtype: int64
