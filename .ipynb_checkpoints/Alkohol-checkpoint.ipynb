# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def draw_plot(x,y,x_avg,y_avg,mean_alc):
    plt.figure().set_figwidth(20)
    plt.xticks(rotation=90)

    plt.plot(x_avg, y_avg, color='black', linestyle='dashed', linewidth=2)
    bars = plt.bar(x,y)

    for bar in bars:
        if bar.get_height() < mean_alc:
            bar.set_color('blue')
        else:
            bar.set_color('brown')

    plt.xlabel('Countries', fontdict={'size':30})
    plt.ylabel('Total litries of alkohol', fontdict={'size':20})
    
    plt.show()

# %%
def add_continent(continents, new_continent):
    for continent in continents:
        if continent[0] == new_continent:
            return continents
    continents.append([new_continent, 0])
    return continents

# %%
alcohol = pd.read_csv('./alkohol/drinks.csv')
alcohol[['country', 'beer_servings']].iloc[:5]
# Out:
#        country  beer_servings
# 0  Afghanistan              0
# 1      Albania             89
# 2      Algeria             25
# 3      Andorra            245
# 4       Angola            217

# %%
alcohol.groupby('country').mean().sort_values('beer_servings', ascending=False).head(10)
# Out:
#                 index  beer_servings  spirit_servings  wine_servings  \
# country
# Namibia         117.0          376.0              3.0            1.0
# Czech Republic   45.0          361.0            170.0          134.0
# Gabon            62.0          347.0             98.0           59.0
# Germany          65.0          346.0            117.0          175.0
# Lithuania        98.0          343.0            244.0           56.0
# Poland          135.0          343.0            215.0           56.0
# Venezuela       188.0          333.0            100.0            3.0
# Ireland          81.0          313.0            118.0          165.0
# Palau           129.0          306.0             63.0           23.0
# Romania         140.0          297.0            122.0          167.0
#
#                 total_litres_of_pure_alcohol
# country
# Namibia                                  6.8
# Czech Republic                          11.8
# Gabon                                    8.9
# Germany                                 11.3
# Lithuania                               12.9
# Poland                                  10.9
# Venezuela                                7.7
# Ireland                                 11.4
# Palau                                    6.9
# Romania                                 10.4

# %% [markdown]
# ### Ranking in every country total sum of consuming litres of alcohol

# %%
alcohol['total'] = alcohol.iloc[:, 2:-1].sum(axis=1)
ranking = alcohol.sort_values('total', ascending=False)
ranking.iloc[:10]
# Out:
#      index             country  beer_servings  spirit_servings  wine_servings  \
# 3        3             Andorra            245              138            312
# 68      68             Grenada            199              438             28
# 45      45      Czech Republic            361              170            134
# 61      61              France            127              151            370
# 141    141  Russian Federation            247              326             73
# 98      98           Lithuania            343              244             56
# 99      99          Luxembourg            236              133            271
# 65      65             Germany            346              117            175
# 75      75             Hungary            234              215            185
# 135    135              Poland            343              215             56
#
#      total_litres_of_pure_alcohol  total
# 3                            12.4    695
# 68                           11.9    665
# 45                           11.8    665
# 61                           11.8    648
# 141                          11.5    646
# 98                           12.9    643
# 99                           11.4    640
# 65                           11.3    638
# 75                           11.3    634
# 135                          10.9    614

# %%
mean_alc = alcohol['total'].mean()

# %%
# First half of countries
x1 = alcohol['country'].iloc[:int(len(alcohol)/2)]
y1 = alcohol['total'].iloc[:int(len(alcohol)/2)]

# Second half of countries
x2 = alcohol['country'].iloc[int(len(alcohol)/2):]
y2 = alcohol['total'].iloc[int(len(alcohol)/2):]

# %%
x_avg = np.arange(0,int(len(alcohol)/2))
y_avg = np.full_like(x_avg, mean_alc)
plt.plot(x_avg, y_avg)

# %%
draw_plot(x1, y1, x_avg, y_avg, mean_alc)

# %%
draw_plot(x2, y2, x_avg, y_avg, mean_alc)

# %%
life_exp = pd.read_csv('./alkohol/lifeexpectancy-verbose.csv')
countires = life_exp[['CountryDisplay', 'RegionDisplay']]
a = countires.loc[life_exp['CountryDisplay'] == "Poland"].iloc[:1]

print(a.iloc[0]['RegionDisplay'])
# Out:
# Europe

# %%
# countires.loc[life_exp['CountryDisplay'] == "Antigua and Barbuda"]

# %%
continents = []

for country in alcohol['country']:
#     print(f"{region}, {country}\n")
    region = countires.loc[life_exp['CountryDisplay'] == country].iloc[:1]
    if not len(region):
        continue
    region = region.iloc[0]['RegionDisplay']
    add_continent(continents, region)
        
    for i in range(len(continents)):
        if continents[i][0] == region:
            total = alcohol.loc[alcohol['country'] == country]
            total = total.iloc[0]['total']
            continents[i][1]+=total

# %%
print(continents)
# Out:
# [['Eastern Mediterranean', 710], ['Europe', 21372], ['Africa', 4352], ['Americas', 9105], ['Western Pacific', 4139], ['South_East Asia', 647]]

# %%
x = [continents[i][0] for i in range(len(continents))]
y = [continents[i][1] for i in range(len(continents))]
plt.pie(y, labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1de19fce970>,
#   <matplotlib.patches.Wedge at 0x1de19fce2e0>,
#   <matplotlib.patches.Wedge at 0x1de19fce550>,
#   <matplotlib.patches.Wedge at 0x1de19cc1820>,
#   <matplotlib.patches.Wedge at 0x1de19cc1670>,
#   <matplotlib.patches.Wedge at 0x1de19cc1d30>],
#  [Text(1.0983176371916556, 0.060814207499061385, 'Eastern Mediterranean'),
#   Text(-0.22376868933095462, 1.0769993378248228, 'Europe'),
#   Text(-0.883529189551186, -0.6552680147932025, 'Africa'),
#   Text(0.1270195033238721, -1.0926417737645568, 'Americas'),
#   Text(1.0029266953234035, -0.45181638284559505, 'Western Pacific'),
#   Text(1.0986028825925653, -0.055422976817435375, 'South_East Asia')])
